# %%
import scipy
from scipy.stats import norm  # Importa el submodulo asociado a la distribución normal
1 - norm.cdf(100, loc=100, scale=10)  # Calcula P(X>100)
# Out:
# 0.5

# %%
norm.cdf(85, 100, 10)  # Calcula la función de distribución para 85, P(X<85)
# Out:
# 0.06680720126885807

# %%
norm.cdf(112, 100, 10)  # Calcula la función de distribución para 112
# Out:
# 0.8849303297782918

# %%
1 - norm.cdf(108, 100, 10)
# Out:
# 0.21185539858339664

# %%
# Out:
# array([0.63801303, 0.68595068, 0.94169904, 0.74630866, 0.49502069,
#        0.40668005, 0.27807529, 0.05084775, 0.34552008, 0.85367531,
#        0.77872229, 0.36279007, 0.06420768, 0.79545432, 0.68932822,
#        0.27346508, 0.39512737, 0.05732224, 0.03919112, 0.30577248,
#        0.6482481 , 0.57963552, 0.69418438, 0.00977646, 0.08437033,
#        0.31387127, 0.63133461, 0.3887824 , 0.73069843, 0.20645441,
#        0.02106333, 0.90785052, 0.42299015, 0.23075089, 0.70878463,
#        0.61519045, 0.97299456, 0.17135038, 0.61966735, 0.99007512,
#        0.82975919, 0.9320078 , 0.57367995, 0.49846152, 0.77039499,
#        0.51022935, 0.58220818, 0.65411852, 0.64418293, 0.35575191,
#        0.48172204, 0.87256101, 0.43108185, 0.70297438, 0.43610163,
#        0.18152386, 0.25880925, 0.48935283, 0.17906113, 0.78389496,
#        0.16548879, 0.81021499, 0.8276769 , 0.19183259, 0.91350837,
#        0.16813028, 0.79120887, 0.85898183, 0.30320722, 0.82657041,
# ...

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
x1=np.random.normal(0, 0.2,100)
x2=np.random.normal(0.3, 0.2,100)
plt.scatter(x1,np.random.random(100),c="r")
plt.scatter(x2,np.random.random(100)+1,c="b")

# %%
from numpy.lib.histograms import histogram
histogram
# Out:
# <function numpy.histogram(a, bins=10, range=None, normed=None, weights=None, density=None)>

# %%
plt.hist(x1,20, density=True, color="b", label="muestra")
# Out:
# (array([0.18637214, 0.55911643, 0.        , 0.        , 0.        ,
#         1.11823287, 1.30460501, 2.23646573, 1.86372144, 1.6773493 ,
#         1.86372144, 2.05009359, 2.23646573, 0.93186072, 0.74548858,
#         0.18637214, 0.74548858, 0.37274429, 0.        , 0.55911643]),
#  array([-0.57342794, -0.51977185, -0.46611576, -0.41245968, -0.35880359,
#         -0.3051475 , -0.25149142, -0.19783533, -0.14417924, -0.09052316,
#         -0.03686707,  0.01678902,  0.07044511,  0.12410119,  0.17775728,
#          0.23141337,  0.28506945,  0.33872554,  0.39238163,  0.44603772,
#          0.4996938 ]),
#  <BarContainer object of 20 artists>)

# %%
plt.bar(x1,x2p)
# Out:
# <BarContainer object of 100 artists>

# %%
mean, var, skew, kurt = norm.stats(moments='mvsk')

# %%
x = np.linspace(norm.ppf(0.6),
                norm.ppf(0.4), 100)
ax.plot(x, norm.pdf(x),
       'r-', lw=5, alpha=0.3, label='norm pdf')

# %%
rv = norm()
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')

# %%
vals = norm.ppf([0.001, 0.5, 0.999])
np.allclose([0.001, 0.5, 0.999], norm.cdf(vals))
True
# Out:
# True

# %%
r = norm.rvs(size=1000)

# %%
ax.hist(r, density=True, bins='auto', histtype='stepfilled', alpha=0.2)
ax.set_xlim([x[0], x[-1]])
ax.legend(loc='best', frameon=False)
plt.show()

# %%
from numpy.lib.histograms import histogram
histogram
# Out:
# <function numpy.histogram(a, bins=10, range=None, normed=None, weights=None, density=None)>

# %%
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt
import seaborn as sns
X1_Y1=numpy.random.multivariate_normal([0,1],[[1,0],[0,1]],500)
X2_Y2=numpy.random.multivariate_normal([5,6],[[1,0],[0,1]],500)
plt.scatter(X1_Y1[:,0],X1_Y1[:,1])
plt.scatter(X2_Y2[:,0],X2_Y2[:,1])
plt.show()
plt.hist(X1_Y1[:,0])
plt.hist(X2_Y2[:,0])
plt.show()
plt.hist(numpy.concatenate((X1_Y1[:,0],X2_Y2[:,0])))
plt.show()
plt.hist(numpy.concatenate((X1_Y1[:,1],X2_Y2[:,1])),bins=2)
plt.show()
sns.jointplot(x=numpy.concatenate((X1_Y1[:,0],X2_Y2[:,0])),y=numpy.concatenate((X1_Y1[:,1],X2_Y2[:,1])))
plt.show()
